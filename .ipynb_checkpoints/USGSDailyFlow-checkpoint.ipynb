# %% [markdown]
# # Introduction to USGS Data Retrieval Python Library
# This workbook illustrates the use of the USGS data retrieval library for importing and graphing daily and/or instantaneous (usually 15-minute) dischrage data. Full documentation is available at https://doi-usgs.github.io/dataretrieval-python/examples/USGS_dataretrieval_DailyValues_Examples.html.  For students interested in the R programming language, a similar set of examples are available at https://waterdata.usgs.gov/blog/dataretrieval/
#
# # Install the USGS dataretrieval library
#
# To start, first install using pip (for most Python environments, from the command prompt) or using Anaconda's command prompt (if you have an Anaconda-based environment).
#
# pip install dataretrieval
#
# or
#
# conda install conda-forge::dataretrieval
#
# or, for a Google Colab notebook,
#
# %pip install dataretrieval
#
# # Now import the library

# %%
from dataretrieval import nwis

# %% [markdown]
# # Define the site number, parameter to plot, and dates
# You can find the site from the USGS map interface at https://waterdata.usgs.gov
# Here, we're plotting discharge in cubic feet per second, which has code 00060.  Other codes are at https://help.waterdata.usgs.gov/codes-and-parameters/parameters.  The most commonly measured parameters are under the physical parameter codes.  For example, discharge in cfs is code 00060, and celsius temperature is 00010.

# %%
# Set the parameters needed to retrieve data
siteNumber = "12167000" # North Fork Stillaguamish River Near Arlington
parameterCode = "00060" # Daily Discharge.  Use 00061 for instantaneous (so on 15-minute basis)
startDate = "2020-10-01"
endDate = "2020-11-01"

# %% [markdown]
# # Download the data
# The resulting data are formated as an array of Pandas dataframes.  Here, the length of the resulting dataframe is displayed as plain text. To simplify things, copy the first in the array of dataframes into a new variable called dfDailyStreamflow.

# %%
dailyStreamflow = nwis.get_dv(sites=siteNumber, parameterCd=parameterCode, start=startDate, end=endDate) 
print("Retrieved " + str(len(dailyStreamflow[0])) + " data values.")
dfDailyStreamflow = dailyStreamflow[0]
# Out:
# Retrieved 32 data values.

# %%
startDate
# Out:
# '2020-10-01'

# %% [markdown]
# We can display the data as follows:

# %%
dfDailyStreamflow
# Out:
#                            00060_Mean 00060_Mean_cd   site_no
# datetime
# 2020-10-01 00:00:00+00:00       531.0             A  12167000
# 2020-10-02 00:00:00+00:00       471.0             A  12167000
# 2020-10-03 00:00:00+00:00       427.0             A  12167000
# 2020-10-04 00:00:00+00:00       393.0             A  12167000
# 2020-10-05 00:00:00+00:00       369.0             A  12167000
# 2020-10-06 00:00:00+00:00       347.0             A  12167000
# 2020-10-07 00:00:00+00:00       330.0             A  12167000
# 2020-10-08 00:00:00+00:00       316.0             A  12167000
# 2020-10-09 00:00:00+00:00       312.0             A  12167000
# 2020-10-10 00:00:00+00:00      3380.0             A  12167000
# 2020-10-11 00:00:00+00:00      2630.0             A  12167000
# 2020-10-12 00:00:00+00:00      5580.0             A  12167000
# 2020-10-13 00:00:00+00:00      3830.0             A  12167000
# 2020-10-14 00:00:00+00:00      4520.0             A  12167000
# 2020-10-15 00:00:00+00:00      2770.0             A  12167000
# 2020-10-16 00:00:00+00:00      3560.0             A  12167000
# 2020-10-17 00:00:00+00:00      3910.0             A  12167000
# 2020-10-18 00:00:00+00:00      4170.0             A  12167000
# 2020-10-19 00:00:00+00:00      3540.0             A  12167000
# 2020-10-20 00:00:00+00:00      2430.0             A  12167000
# 2020-10-21 00:00:00+00:00      1790.0             A  12167000
# 2020-10-22 00:00:00+00:00      1450.0             A  12167000
# 2020-10-23 00:00:00+00:00      1410.0             A  12167000
# 2020-10-24 00:00:00+00:00      1720.0             A  12167000
# 2020-10-25 00:00:00+00:00      1260.0             A  12167000
# 2020-10-26 00:00:00+00:00      1100.0             A  12167000
# 2020-10-27 00:00:00+00:00      1000.0             A  12167000
# 2020-10-28 00:00:00+00:00       979.0             A  12167000
# 2020-10-29 00:00:00+00:00       955.0             A  12167000
# 2020-10-30 00:00:00+00:00      1280.0             A  12167000
# 2020-10-31 00:00:00+00:00      1150.0             A  12167000
# 2020-11-01 00:00:00+00:00       957.0             A  12167000

# %% [markdown]
# # Optional: Clean the data
# The next step is optional, but it can be nice to simplify the dataframe by removing extraneous columns and
# adding intuitive names to the column headers.

# %%
#Clean flow data
dfQ = dfDailyStreamflow.drop(columns=['00060_Mean_cd','site_no'])
dfQ = dfQ.rename(columns={'00060_Mean':'Q(cfs)'})
dfQ.index = dfQ.index.rename('datetime')
#print out the data frame for inspection
dfQ
# Out:
#                            Q(cfs)
# datetime
# 2020-10-01 00:00:00+00:00   531.0
# 2020-10-02 00:00:00+00:00   471.0
# 2020-10-03 00:00:00+00:00   427.0
# 2020-10-04 00:00:00+00:00   393.0
# 2020-10-05 00:00:00+00:00   369.0
# 2020-10-06 00:00:00+00:00   347.0
# 2020-10-07 00:00:00+00:00   330.0
# 2020-10-08 00:00:00+00:00   316.0
# 2020-10-09 00:00:00+00:00   312.0
# 2020-10-10 00:00:00+00:00  3380.0
# 2020-10-11 00:00:00+00:00  2630.0
# 2020-10-12 00:00:00+00:00  5580.0
# 2020-10-13 00:00:00+00:00  3830.0
# 2020-10-14 00:00:00+00:00  4520.0
# 2020-10-15 00:00:00+00:00  2770.0
# 2020-10-16 00:00:00+00:00  3560.0
# 2020-10-17 00:00:00+00:00  3910.0
# 2020-10-18 00:00:00+00:00  4170.0
# 2020-10-19 00:00:00+00:00  3540.0
# 2020-10-20 00:00:00+00:00  2430.0
# 2020-10-21 00:00:00+00:00  1790.0
# 2020-10-22 00:00:00+00:00  1450.0
# 2020-10-23 00:00:00+00:00  1410.0
# 2020-10-24 00:00:00+00:00  1720.0
# 2020-10-25 00:00:00+00:00  1260.0
# 2020-10-26 00:00:00+00:00  1100.0
# 2020-10-27 00:00:00+00:00  1000.0
# 2020-10-28 00:00:00+00:00   979.0
# 2020-10-29 00:00:00+00:00   955.0
# 2020-10-30 00:00:00+00:00  1280.0
# 2020-10-31 00:00:00+00:00  1150.0
# 2020-11-01 00:00:00+00:00   957.0

# %% [markdown]
#    # Plot the data
# We can also make a simple timeseries plot using the standard matplotlib syntax.  Note that the data looks jagged because we are only plotting the mean value for each day, so full hydrographs are not resolved.

# %%
ax = dfQ.plot(y='Q(cfs)')
ax.set_xlabel('Date')
ax.set_ylabel('Streamflow (cfs)')
# Out:
# Text(0, 0.5, 'Streamflow (cfs)')

# %% [markdown]
# # Now Download Instantaneous Data
# Note here that using the instantaneous download function results in many more data points. This ensures that we resolve all the hydrographs.  You won't need this much data for every assignment, but it can be helpful for making smooth graphs.

# %%
# Get instanteous data
discharge = nwis.get_iv(sites=siteNumber, parameterCd=parameterCode, start=startDate, end=endDate)
print('Retrieved ' + str(len(discharge[0])) + ' data values.')
dfInstantaneous=discharge[0]
dfInstantaneous
# Out:
# Retrieved 3076 data values.
#                                00060 00060_cd   site_no
# datetime
# 2020-10-01T00:00:00.000-07:00  569.0        A  12167000
# 2020-10-01T00:15:00.000-07:00  576.0        A  12167000
# 2020-10-01T00:30:00.000-07:00  576.0        A  12167000
# 2020-10-01T00:45:00.000-07:00  569.0        A  12167000
# 2020-10-01T01:00:00.000-07:00  569.0        A  12167000
# ...                              ...      ...       ...
# 2020-11-01T22:45:00.000-08:00  915.0        A  12167000
# 2020-11-01T23:00:00.000-08:00  906.0        A  12167000
# 2020-11-01T23:15:00.000-08:00  906.0        A  12167000
# 2020-11-01T23:30:00.000-08:00  906.0        A  12167000
# 2020-11-01T23:45:00.000-08:00  906.0        A  12167000
#
# [3076 rows x 3 columns]

# %% [markdown]
# # Optional: Clean the Instantaneous Data

# %%
#Clean flow data
dfQinst = dfInstantaneous.drop(columns=['00060_cd','site_no'])
dfQinst = dfQinst.rename(columns={'00060':'Q(cfs)'})
dfQinst.index = dfQinst.index.rename('datetime')
#print out the data frame for inspection
dfQinst
# Out:
#                                Q(cfs)
# datetime
# 2020-10-01T00:00:00.000-07:00   569.0
# 2020-10-01T00:15:00.000-07:00   576.0
# 2020-10-01T00:30:00.000-07:00   576.0
# 2020-10-01T00:45:00.000-07:00   569.0
# 2020-10-01T01:00:00.000-07:00   569.0
# ...                               ...
# 2020-11-01T22:45:00.000-08:00   915.0
# 2020-11-01T23:00:00.000-08:00   906.0
# 2020-11-01T23:15:00.000-08:00   906.0
# 2020-11-01T23:30:00.000-08:00   906.0
# 2020-11-01T23:45:00.000-08:00   906.0
#
# [3076 rows x 1 columns]

# %% [markdown]
# # Plot the instantaneous data
# Now the graph should be much smoother.

# %%
ax2 = dfQinst.plot(y='Q(cfs)')
ax2.set_xlabel('Date')
ax2.set_ylabel('Streamflow (cfs)')
# Out:
# Text(0, 0.5, 'Streamflow (cfs)')

# %% [markdown]
# # Fix the axis labels

# %%
import pandas as pd
import numpy as np; np.random.seed(42)
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

dfQinst['dt'] = dfQinst.index
dfQinst['dt'] = pd.to_datetime(dfQinst['dt'])

#fig, ax2 = plt.subplots()

ax2 = dfQinst.plot(x='dt', y='Q(cfs)')
ax2.set_xlabel('Date')
ax2.set_ylabel('Streamflow (cfs)')

#Format the x axis labels.  The following formats them every few days
#Use WeekLocator or MonthLocator to set labels at wider intervals
ax2.xaxis.set_major_locator(mdates.DayLocator(interval=3)) 
ax2.xaxis.set_major_formatter(mdates.DateFormatter("%m-%d-%Y"))
plt.gcf().autofmt_xdate() # rotates the date labels

# %% [markdown]
# # Download larger dataset and Tabulate results from a subset of the data
# In the following, we download several years of daily data and summarize it on a weekly, monthly or seasonal basis.

# %%
startDate = "2020-10-01"
endDate = "2022-09-30"

# %%
#summarize as 3-monthly values (starting October 1, so OND, JFM, etc)
#dfseasonal = dfQ.resample('Q-SEP').mean()
# Get daily data
discharge = nwis.get_dv(sites=siteNumber, parameterCd=parameterCode, start=startDate, end=endDate)
print('Retrieved ' + str(len(discharge[0])) + ' data values.')
dfDaily=discharge[0]
dfDaily
#Clean flow data
dfQ = dfDaily.drop(columns=['00060_Mean_cd','site_no'])
dfQ = dfQ.rename(columns={'00060_Mean':'Q(cfs)'})
dfQ.index = dfQ.index.rename('datetime')
#print out the data frame for inspection
dfQ
# Out:
# Retrieved 730 data values.
#                            Q(cfs)
# datetime
# 2020-10-01 00:00:00+00:00   531.0
# 2020-10-02 00:00:00+00:00   471.0
# 2020-10-03 00:00:00+00:00   427.0
# 2020-10-04 00:00:00+00:00   393.0
# 2020-10-05 00:00:00+00:00   369.0
# ...                           ...
# 2022-09-26 00:00:00+00:00   182.0
# 2022-09-27 00:00:00+00:00   181.0
# 2022-09-28 00:00:00+00:00   181.0
# 2022-09-29 00:00:00+00:00   184.0
# 2022-09-30 00:00:00+00:00   182.0
#
# [730 rows x 1 columns]

# %%
#resample on quarterly basis with end of year in specified month of September.
dfseasonal_mean = dfQ.resample('Q-SEP').mean()
dfseasonal_mean['dt'] = dfseasonal_mean.index

ax3 = dfseasonal_mean.plot.bar(y='Q(cfs)')
ax3.set_xlabel('Date')
ax3.set_ylabel('Mean Streamflow by Quarter (cfs)')

ax3.xaxis.set_ticklabels(dfseasonal_mean.index.to_period('Q'))
plt.gcf().autofmt_xdate() # rotates the date labels
# Out:
# C:\Users\WesLa\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1162: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(

# %%
#resample on monthly basis with end of year in specified month of September.
dfmonthly_mean = dfQ.resample('M').mean()
dfmonthly_mean['dt'] = dfmonthly_mean.index

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

#fig, ax4 = plt.subplots()

ax4 = dfmonthly_mean.plot.bar(y='Q(cfs)')
ax4.set_xlabel('Date')
ax4.set_ylabel('Mean Streamflow by month (cfs)')

#Define the number of x labels on graph
num_x_labels = 8

#the following formats the labels
ticklabels = ['']*len(dfmonthly_mean)
skip = len(dfmonthly_mean)//num_x_labels
ticklabels[::skip] = dfmonthly_mean['dt'].iloc[::skip].dt.strftime('%b-%Y')
#see https://man7.org/linux/man-pages/man3/strftime.3.html for date codes

ax4.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate() # rotates the date labels


# fixes the tracker
# https://matplotlib.org/users/recipes.html
def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]
ax4.fmt_xdata = fmt
plt.show()

# %%
#resample on weekly basis 
dfweekly_mean = dfQ.resample('W').mean()
dfweekly_mean['dt'] = dfweekly_mean.index

#fig, ax5 = plt.subplots()

ax5 = dfweekly_mean.plot.bar(y='Q(cfs)')
ax5.set_xlabel('Date')
ax5.set_ylabel('Mean Streamflow by week (cfs)')

#Define the number of x labels on graph
num_x_labels = 10

#the following formats the labels
ticklabels = ['']*len(dfweekly_mean)
skip = len(dfweekly_mean)//num_x_labels
ticklabels[::skip] = dfweekly_mean['dt'].iloc[::skip].dt.strftime('%m-%d-%y')
#see https://man7.org/linux/man-pages/man3/strftime.3.html for date codes

ax5.xaxis.set_major_formatter(mticker.FixedFormatter(ticklabels))
plt.gcf().autofmt_xdate() # rotates the date labels

# fixes the tracker
# https://matplotlib.org/users/recipes.html
def fmt(x, pos=0, max_i=len(ticklabels)-1):
    i = int(x) 
    i = 0 if i < 0 else max_i if i > max_i else i
    return dates[i]
ax5.fmt_xdata = fmt
plt.show()
